# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/DDI-Dataset/DDI-Code.git
# Out:
# Cloning into 'DDI-Code'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 19 (delta 4), reused 7 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (19/19), 10.66 KiB | 341.00 KiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# This command finds the bad code and replaces it with the correct code
# !sed -i 's/DDI_Dataset("DDI",/DDI_Dataset(args.data_dir,/' /content/DDI-Code/eval_ddi.py

# %%
# %cd /content/DDI-Code/

# !python3 eval_ddi.py \
  --model=DeepDerm \
  --data_dir=/content/drive/MyDrive/ddidiversedermatologyimages \
  --eval_dir=/content/drive/MyDrive/DDI-results \
  --use_gpu
# Out:
# /content/DDI-Code
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# 3it [00:57, 17.20s/it]y
# 21it [04:44, 13.56s/it]

# %%
# %cd /content/DDI-Code/

# !python3 eval_ddi.py \
  --model=GroupDRO \
  --data_dir=/content/drive/MyDrive/ddidiversedermatologyimages \
  --eval_dir=/content/drive/MyDrive/DDI-results \
  --use_gpu
# Out:
# /content/DDI-Code
# Downloading...
# From (original): https://drive.google.com/uc?id=193ippDUYpMaOaEyLjd1DNsOiW0aRXL75
# From (redirected): https://drive.google.com/uc?id=193ippDUYpMaOaEyLjd1DNsOiW0aRXL75&confirm=t&uuid=66ebf580-948f-4134-900c-63377183bafc
# To: /content/DDI-Code/DDI-models/groupdro.pth
# 100% 97.7M/97.7M [00:02<00:00, 43.0MB/s]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ...

# %%
# %cd /content/DDI-Code/

# !python3 eval_ddi.py \
  --model=CORAL \
  --data_dir=/content/drive/MyDrive/ddidiversedermatologyimages \
  --eval_dir=/content/drive/MyDrive/DDI-results \
  --use_gpu
# Out:
# /content/DDI-Code
# Downloading...
# From (original): https://drive.google.com/uc?id=18rMU0nRd4LiHN9WkXoDROJ2o2sG1_GD8
# From (redirected): https://drive.google.com/uc?id=18rMU0nRd4LiHN9WkXoDROJ2o2sG1_GD8&confirm=t&uuid=37e50d9b-8011-48c0-adfb-762ff3ec20b9
# To: /content/DDI-Code/DDI-models/coral.pth
# 100% 97.7M/97.7M [00:01<00:00, 57.6MB/s]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ...

# %%
# %cd /content/DDI-Code/

# !python3 eval_ddi.py \
  --model=CDANN \
  --data_dir=/content/drive/MyDrive/ddidiversedermatologyimages \
  --eval_dir=/content/drive/MyDrive/DDI-results \
  --use_gpu
# Out:
# /content/DDI-Code
# Downloading...
# From (original): https://drive.google.com/uc?id=1PvvgQVqcrth840bFZ3ddLdVSL7NkxiRK
# From (redirected): https://drive.google.com/uc?id=1PvvgQVqcrth840bFZ3ddLdVSL7NkxiRK&confirm=t&uuid=12cae988-b7a9-4fd0-b14b-1a971a6122ea
# To: /content/DDI-Code/DDI-models/cdann.pth
# 100% 97.7M/97.7M [00:02<00:00, 48.1MB/s]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ...

# %%
# %cd /content/DDI-Code/

# !python3 eval_ddi.py \
  --model=HAM10000 \
  --data_dir=/content/drive/MyDrive/ddidiversedermatologyimages \
  --eval_dir=/content/drive/MyDrive/DDI-results \
  --use_gpu
